# %%
import csv
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community

# %%
from networkx.drawing.nx_agraph import graphviz_layout
import matplotlib.pyplot as plt

# %%
D = nx.DiGraph()

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-dceb1831-648d-47c3-82e8-c3ebad4cbefc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dceb1831-648d-47c3-82e8-c3ebad4cbefc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving democrats_likes_edges.csv to democrats_likes_edges.csv

# %%
with open('democrats_likes_edges.csv', 'r') as f:
  reader = csv.reader(f)
  next(reader, None)

  for row in f:
    s= row.split(',')
    D.add_edge(s[0], s[1], weight=s[2])

# %%
print(nx.info(D))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 226
# Number of edges: 4287
# Average in degree:  18.9690
# Average out degree:  18.9690

# %%
density = nx.density(D)
print("Network density:", density)
# Out:
# Network density: 0.08430678466076696

# %%
degree_dict = dict(D.degree(D.nodes()))
nx.set_node_attributes(D, degree_dict, 'degree')

# %%
sorted_degree = sorted(degree_dict.items(), key=itemgetter(1), reverse=True)
print("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 nodes by degree:
# ('LeaderHoyer', 160)
# ('WhipClyburn', 97)
# ('RepKClark', 92)
# ('SpeakerPelosi', 90)
# ('RepLindaSanchez', 87)
# ('RepBarbaraLee', 84)
# ('RepPressley', 83)
# ('RepLucyMcBath', 80)
# ('RepJohnLarson', 78)
# ('RepDonBeyer', 76)
# ('RepDelBene', 75)
# ('RepDebDingell', 75)
# ('RepMarciaFudge', 74)
# ('RepWilson', 71)
# ('RepJerryNadler', 70)
# ('RepWexton', 68)
# ('RepShalala', 67)
# ('RepMarkTakano', 66)
# ('RepSylviaGarcia', 66)
# ('RepValDemings', 65)

# %%
betweenness_dict = nx.betweenness_centrality(D) # Run betweenness centrality

# Assign each to an attribute in your network
nx.set_node_attributes(D, betweenness_dict, 'betweenness')

# %%
sorted_betweenness = sorted(betweenness_dict.items(), key=itemgetter(1), reverse=True)

print("Top 20 nodes by betweenness centrality:")
for b in sorted_betweenness[:20]:
    print(b)
# Out:
# Top 20 nodes by betweenness centrality:
# ('LeaderHoyer', 0.04620920880136052)
# ('RepKClark', 0.011399596999893503)
# ('RepLindaSanchez', 0.008771853851561281)
# ('RepCheri', 0.00827385570450778)
# ('WhipClyburn', 0.008117591266217082)
# ('RepLucyMcBath', 0.008058094428408203)
# ('RepWilson', 0.007407130842680936)
# ('RepPressley', 0.007387111045697071)
# ('RepJuanVargas', 0.007219109370100874)
# ('RepMarciaFudge', 0.007072065533564023)
# ('RepMikeLevin', 0.006606429153596972)
# ('RepDebDingell', 0.006555667355756309)
# ('RepBeatty', 0.005955284655566715)
# ('RepJohnLarson', 0.005918161877037928)
# ('RepSherrill', 0.005582140518177341)
# ('RepJeffries', 0.005245098175587799)
# ('RepCasten', 0.005083485357506691)
# ('RepBonnie', 0.004986527380997309)
# ('RepJerryNadler', 0.004943454552806566)
# ('RepUnderwood', 0.004836528721329213)

# %%
#First get the top 20 nodes by betweenness as a list
top_betweenness = sorted_betweenness[:20]

#Then find and print their degree
for tb in top_betweenness: # Loop through top_betweenness
    degree = degree_dict[tb[0]] # Use degree_dict to access a node's degree, see footnote 2
    print("Name:", tb[0], "| Betweenness Centrality:", tb[1], "| Degree:", degree)
# Out:
# Name: LeaderHoyer | Betweenness Centrality: 0.04620920880136052 | Degree: 160
# Name: RepKClark | Betweenness Centrality: 0.011399596999893503 | Degree: 92
# Name: RepLindaSanchez | Betweenness Centrality: 0.008771853851561281 | Degree: 87
# Name: RepCheri | Betweenness Centrality: 0.00827385570450778 | Degree: 64
# Name: WhipClyburn | Betweenness Centrality: 0.008117591266217082 | Degree: 97
# Name: RepLucyMcBath | Betweenness Centrality: 0.008058094428408203 | Degree: 80
# Name: RepWilson | Betweenness Centrality: 0.007407130842680936 | Degree: 71
# Name: RepPressley | Betweenness Centrality: 0.007387111045697071 | Degree: 83
# Name: RepJuanVargas | Betweenness Centrality: 0.007219109370100874 | Degree: 58
# Name: RepMarciaFudge | Betweenness Centrality: 0.007072065533564023 | Degree: 74
# Name: RepMikeLevin | Betweenness Centrality: 0.006606429153596972 | Degree: 63
# Name: RepDebDingell | Betweenness Centrality: 0.006555667355756309 | Degree: 75
# Name: RepBeatty | Betweenness Centrality: 0.005955284655566715 | Degree: 56
# Name: RepJohnLarson | Betweenness Centrality: 0.005918161877037928 | Degree: 78
# Name: RepSherrill | Betweenness Centrality: 0.005582140518177341 | Degree: 55
# Name: RepJeffries | Betweenness Centrality: 0.005245098175587799 | Degree: 56
# Name: RepCasten | Betweenness Centrality: 0.005083485357506691 | Degree: 55
# Name: RepBonnie | Betweenness Centrality: 0.004986527380997309 | Degree: 57
# Name: RepJerryNadler | Betweenness Centrality: 0.004943454552806566 | Degree: 70
# Name: RepUnderwood | Betweenness Centrality: 0.004836528721329213 | Degree: 60

# %%
nx.draw_random(D, with_labels=True, node_color='b',
        node_size=100, arrows=False, alpha=0.6)
plt.show()

# %%
nx.draw(D, pos = nx.nx_pydot.graphviz_layout(D), node_size=60, node_color='blue', \
    linewidths=0.99, font_size=5, font_weight='bold', with_labels=True)
plt.show()

# %%
R = nx.DiGraph()

# %%
from google.colab import files
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-6598d448-5c51-4ccb-976c-932949a00c47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6598d448-5c51-4ccb-976c-932949a00c47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving republican_likes_edges.csv to republican_likes_edges.csv

# %%
with open('republican_likes_edges.csv', 'r') as f:
  reader = csv.reader(f)
  next(reader, None)

  for row in f:
    s= row.split(',')
    R.add_edge(s[0], s[1], weight=s[2])

# %%
print(nx.info(R))
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 194
# Number of edges: 2356
# Average in degree:  12.1443
# Average out degree:  12.1443

# %%
density = nx.density(R)
print("Network density:", density)
# Out:
# Network density: 0.0629239891031462

# %%
degree_dict = dict(R.degree(R.nodes()))
nx.set_node_attributes(R, degree_dict, 'degree')

# %%
sorted_degree = sorted(degree_dict.items(), key=itemgetter(1), reverse=True)
print("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 nodes by degree:
# ('SteveScalise', 146)
# ('GOPLeader', 137)
# ('RepBradWenstrup', 84)
# ('RepKevinBrady', 68)
# ('RepRichHudson', 58)
# ('michaelcburgess', 56)
# ('RepAndyBiggsAZ', 55)
# ('cathymcmorris', 55)
# ('HerreraBeutler', 54)
# ('RepDLesko', 51)
# ('RepDougCollins', 50)
# ('Jim_Jordan', 50)
# ('RepMikeJohnson', 49)
# ('RepDonBacon', 49)
# ('RepHartzler', 47)
# ('RepArrington', 46)
# ('RepJeffDuncan', 41)
# ('CongressmanHice', 41)
# ('RepTedBudd', 41)
# ('GReschenthaler', 41)

# %%
betweenness_dict = nx.betweenness_centrality(R) # Run betweenness centrality

# Assign each to an attribute in your network
nx.set_node_attributes(R, betweenness_dict, 'betweenness')

# %%
sorted_betweenness = sorted(betweenness_dict.items(), key=itemgetter(1), reverse=True)

print("Top 20 nodes by betweenness centrality:")
for b in sorted_betweenness[:20]:
    print(b)
# Out:
# Top 20 nodes by betweenness centrality:
# ('SteveScalise', 0.06208637437386348)
# ('GOPLeader', 0.06192467527402033)
# ('RepRichHudson', 0.012914496038345206)
# ('cathymcmorris', 0.009456993032265605)
# ('Jim_Jordan', 0.009353847918697922)
# ('HerreraBeutler', 0.00828770232207351)
# ('RepMikeJohnson', 0.0060777323831641234)
# ('RepHartzler', 0.006027981520883302)
# ('RepRickCrawford', 0.0055642094456626765)
# ('RepDLesko', 0.0052295583762228945)
# ('CongressmanHice', 0.005031389398719962)
# ('RepDougCollins', 0.004754117934051264)
# ('RepRussFulcher', 0.004585477022727139)
# ('RepJenniffer', 0.0044307257908042085)
# ('RepGosar', 0.004153405121430004)
# ('RepRutherfordFL', 0.004145702929137807)
# ('michaelcburgess', 0.004142423650133416)
# ('RepTomEmmer', 0.004071267275514669)
# ('RepKevinBrady', 0.0037971761071263653)
# ('RepAndyBiggsAZ', 0.0037172555271318317)

# %%
#First get the top 20 nodes by betweenness as a list
top_betweenness = sorted_betweenness[:20]

#Then find and print their degree
for tb in top_betweenness: # Loop through top_betweenness
    degree = degree_dict[tb[0]] # Use degree_dict to access a node's degree, see footnote 2
    print("Name:", tb[0], "| Betweenness Centrality:", tb[1], "| Degree:", degree)
# Out:
# Name: SteveScalise | Betweenness Centrality: 0.06208637437386348 | Degree: 146
# Name: GOPLeader | Betweenness Centrality: 0.06192467527402033 | Degree: 137
# Name: RepRichHudson | Betweenness Centrality: 0.012914496038345206 | Degree: 58
# Name: cathymcmorris | Betweenness Centrality: 0.009456993032265605 | Degree: 55
# Name: Jim_Jordan | Betweenness Centrality: 0.009353847918697922 | Degree: 50
# Name: HerreraBeutler | Betweenness Centrality: 0.00828770232207351 | Degree: 54
# Name: RepMikeJohnson | Betweenness Centrality: 0.0060777323831641234 | Degree: 49
# Name: RepHartzler | Betweenness Centrality: 0.006027981520883302 | Degree: 47
# Name: RepRickCrawford | Betweenness Centrality: 0.0055642094456626765 | Degree: 38
# Name: RepDLesko | Betweenness Centrality: 0.0052295583762228945 | Degree: 51
# Name: CongressmanHice | Betweenness Centrality: 0.005031389398719962 | Degree: 41
# Name: RepDougCollins | Betweenness Centrality: 0.004754117934051264 | Degree: 50
# Name: RepRussFulcher | Betweenness Centrality: 0.004585477022727139 | Degree: 34
# Name: RepJenniffer | Betweenness Centrality: 0.0044307257908042085 | Degree: 22
# Name: RepGosar | Betweenness Centrality: 0.004153405121430004 | Degree: 28
# Name: RepRutherfordFL | Betweenness Centrality: 0.004145702929137807 | Degree: 24
# Name: michaelcburgess | Betweenness Centrality: 0.004142423650133416 | Degree: 56
# Name: RepTomEmmer | Betweenness Centrality: 0.004071267275514669 | Degree: 37
# Name: RepKevinBrady | Betweenness Centrality: 0.0037971761071263653 | Degree: 68
# Name: RepAndyBiggsAZ | Betweenness Centrality: 0.0037172555271318317 | Degree: 55

# %%
nx.draw_random(R, with_labels=True, node_color='r',
        node_size=100, arrows=False, alpha=0.6)
plt.show()

# %%
nx.draw(R, pos = nx.nx_pydot.graphviz_layout(R), node_size=60, node_color='red', \
    linewidths=0.99, font_size=5, font_weight='bold', with_labels=True)
plt.show()

# %%
nx.draw(D,pos = nx.draw(R, with_labels=True, node_color='r',
        node_size=100, arrows=False, alpha=0.5), with_labels=True, node_color='b',
        node_size=100, arrows=False, alpha=0.5)
plt.show()
